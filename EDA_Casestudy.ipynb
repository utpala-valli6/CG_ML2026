# %%
#Import Libraries
import numpy as np #Faster Data Processing(arrays)
import pandas as pd #EDA Purpose

# %%
#Loading the data
data = pd.read_csv('titanic.csv')
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 118.9 KB

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='str')

# %%
data.dtypes;
data.select_dtypes(include='object')
data.select_dtypes(include=['int','float'])
# Out:
# C:\Users\utpal\AppData\Local\Temp\ipykernel_8008\4115214050.py:2: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   data.select_dtypes(include='object')
#      PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0              1         0       3  22.0      1      0   7.2500
# 1              2         1       1  38.0      1      0  71.2833
# 2              3         1       3  26.0      0      0   7.9250
# 3              4         1       1  35.0      1      0  53.1000
# 4              5         0       3  35.0      0      0   8.0500
# ...

# %%
print('Total number of passengers in ship are',len(data))
# Out:
# Total number of passengers in ship are 891

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data.describe(include='object')
# Out:
# C:\Users\utpal\AppData\Local\Temp\ipykernel_8008\3382516499.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   data.describe(include='object')
#                            Name   Sex  Ticket Cabin Embarked
# count                       891   891     891   204      889
# unique                      891     2     681   147        3
# top     Braund, Mr. Owen Harris  male  347082    G6        S
# freq                          1   577       7     4      644

# %%
data['Sex']
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: Sex, Length: 891, dtype: str

# %%
data['Ticket']
# Out:
# 0             A/5 21171
# 1              PC 17599
# 2      STON/O2. 3101282
# 3                113803
# 4                373450
#              ...
# 886              211536
# 887              112053
# 888          W./C. 6607
# 889              111369
# 890              370376
# Name: Ticket, Length: 891, dtype: str

# %%
data['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: str

# %%
data['Cabin'].unique()
# Out:
# <ArrowStringArray>
# [          nan,         'C85',        'C123',         'E46',          'G6',
#         'C103',         'D56',          'A6', 'C23 C25 C27',         'B78',
#  ...
#         'B102',         'B69',         'E49',         'C47',         'D28',
#          'E17',         'A24',         'C50',         'B42',        'C148']
# Length: 148, dtype: str

# %%
data['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
data['Cabin'].value_counts()
# Out:
# Cabin
# G6             4
# C23 C25 C27    4
# B96 B98        4
# F33            3
# E101           3
#               ..
# E17            1
# A24            1
# C50            1
# B42            1
# C148           1
# Name: count, Length: 147, dtype: int64

# %%
data['Pclass'].value_counts()
data['Pclass'].value_counts(ascending=True)
# Out:
# Pclass
# 2    184
# 1    216
# 3    491
# Name: count, dtype: int64

# %%
data['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
data['Age'].value_counts()
# Out:
# Age
# 24.00    30
# 22.00    27
# 18.00    26
# 28.00    25
# 19.00    25
#          ..
# 24.50     1
# 0.67      1
# 0.42      1
# 34.50     1
# 74.00     1
# Name: count, Length: 88, dtype: int64

# %%
data['Age'].value_counts().head(30)
# Out:
# Age
# 24.0    30
# 22.0    27
# 18.0    26
# 28.0    25
# 19.0    25
# 30.0    25
# 21.0    24
# 25.0    23
# 36.0    22
# 29.0    20
# 26.0    18
# 35.0    18
# 27.0    18
# 32.0    18
# 31.0    17
# 16.0    17
# 20.0    15
# 34.0    15
# 33.0    15
# 23.0    15
# 39.0    14
# 40.0    13
# 42.0    13
# 17.0    13
# 45.0    12
# 38.0    11
# 2.0     10
# 4.0     10
# 50.0    10
# 47.0     9
# Name: count, dtype: int64

# %%
data.sample(15)
# Out:
#      PassengerId  Survived  Pclass  \
# 855          856         1       3
# 163          164         0       3
# 290          291         1       1
# 498          499         0       1
# 674          675         0       2
# 390          391         1       1
# 413          414         0       2
# 134          135         0       2
# 213          214         0       2
# 701          702         1       1
# 227          228         0       3
# 203          204         0       3
# 407          408         1       2
# 572          573         1       1
# 702          703         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 855                       Aks, Mrs. Sam (Leah Rosen)  female  18.0      0
# 163                                  Calic, Mr. Jovo    male  17.0      0
# 290                     Barber, Miss. Ellen "Nellie"  female  26.0      0
# 498  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0      1
# ...

# %%
import matplotlib.pyplot as plt

# %%
counts,edges,bars = plt.hist(data['Age'],bins=15,color='pink')
print(counts)
print(bars)
plt.xlabel("Age")
plt.ylabel("Count")
plt.bar_label(bars)
plt.title("Age Distribution")
plt.show()
# Out:
# [ 44.  24.  32. 104. 115. 127.  80.  59.  49.  30.  22.  17.   4.   6.
#    1.]
# <BarContainer object of 15 artists>

# %%
data['Sex'].value_counts().plot(kind='bar',color='lightblue')
# Out:
# <Axes: xlabel='Sex'>

# %%
data['Pclass'].value_counts().plot(kind='barh',color='lavender')
# Out:
# <Axes: ylabel='Pclass'>

# %%
plt.bar(data['Survived'],data['Sex'],color='palegreen')
plt.xlabel("Survived Rate")
plt.ylabel("Gender")
plt.title("Gender Survived Distribution")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
index=data['Survived'].value_counts().keys().tolist()
print(index)
labels=data['Survived'].value_counts().values.tolist()
print(labels)
# Out:
# [0, 1]
# [549, 342]

# %%
plt.pie(x = labels,
        labels = ['Dead', 'Alive'],
        colors = ['dimgray','lightgray'],
        autopct="%.1f%%",)
plt.title("Survived Distribution",color='navy')
plt.legend()
plt.show()

# %%
plt.pie(x = [577,314],
        labels = ['Male', 'Female'],
        colors = ['lightblue','pink'],
        autopct="%.1f%%",)
plt.title("Survived Distribution",color='navy')
plt.legend()
plt.show()

# %%
plt.scatter(x=data['Age'],y=data['Fare'],color='tan')
plt.xlabel("Age")
plt.ylabel("Fare")
plt.title("Age VS Fare Distribution")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import plotly

# %%
# !pip install cufflinks
# Out:
# ...
# [notice] A new release of pip is available: 25.0.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import plotly as py
import plotly.graph_objects as go

# %%
trace = go.Histogram(x = data['Age'], nbinsx=20, marker={'color' : 'plum'})
layout = go.Layout(title="Age Distribution")
fig = go.Figure(data=trace,layout = layout)
fig

# %%
print(index)
print(labels)
# Out:
# [0, 1]
# [549, 342]

# %%
trace=go.Pie(labels=['Dead','Alive'],values=[549,342])
layout=go.Layout(title='Survived Distribution')
fig=go.Figure(data=trace, layout=layout)
fig.show()

# %%
trace = go.Box(x=data['Pclass'],y=data['Age'],marker={'color':'plum'})
layout=go.Layout(title='Age VS Pclass Distribution')
fig = go.Figure(data=trace, layout=layout)
fig.show()

# %%
trace = go.Scatter(x=data['Age'],y=data['Fare'],mode='markers',marker={'color':'red'})
layout=go.Layout(title='Age VS Fare Distribution')
fig = go.Figure(data=trace, layout=layout)
fig.show()

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data['Age'] = data['Age'].fillna(data['Age'].mean(),inplace=True)
data.isnull().sum()
# Out:
# C:\Users\utpal\AppData\Local\Temp\ipykernel_8008\3943197569.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   data['Age'] = data['Age'].fillna(data['Age'].mean(),inplace=True)
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# ...

# %%
pclass = pd.get_dummies(data['Pclass'],drop_first=True,dtype=int)
pclass
# Out:
#      2  3
# 0    0  1
# 1    0  0
# 2    0  1
# 3    0  0
# 4    0  1
# ..  .. ..
# 886  1  0
# 887  0  0
# 888  0  1
# 889  0  0
# 890  0  1
#
# [891 rows x 2 columns]

# %%
pclass = pd.get_dummies(data['Pclass'],drop_first=True)
pclass
# Out:
#          2      3
# 0    False   True
# 1    False  False
# 2    False   True
# 3    False  False
# 4    False   True
# ..     ...    ...
# 886   True  False
# 887  False  False
# 888  False   True
# 889  False  False
# 890  False   True
#
# [891 rows x 2 columns]

# %%
embarked = pd.get_dummies(data['Embarked'],drop_first=True)
embarked
# Out:
#          Q      S
# 0    False   True
# 1    False  False
# 2    False   True
# 3    False   True
# 4    False   True
# ..     ...    ...
# 886  False   True
# 887  False   True
# 888  False   True
# 889  False  False
# 890   True  False
#
# [891 rows x 2 columns]

# %%
gender = pd.get_dummies(data['Sex'],drop_first=True)
gender
# Out:
#       male
# 0     True
# 1    False
# 2    False
# 3    False
# 4     True
# ..     ...
# 886   True
# 887  False
# 888  False
# 889   True
# 890   True
#
# [891 rows x 1 columns]

# %%
final_data = pd.concat([data,pclass,gender,embarked],axis=1)
final_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
final_data.columns
# Out:
# Index(['PassengerId',    'Survived',      'Pclass',        'Name',
#                'Sex',         'Age',       'SibSp',       'Parch',
#             'Ticket',        'Fare',       'Cabin',    'Embarked',
#                    2,             3,        'male',           'Q',
#                  'S'],
#       dtype='object')

# %%
final_data.drop(columns=['PassengerId','Name','Pclass','Sex','Ticket','Embarked'],inplace=True)
final_data.head()
# Out:
#    Survived   Age  SibSp  Parch     Fare Cabin      2      3   male      Q  \
# 0         0  22.0      1      0   7.2500   NaN  False   True   True  False
# 1         1  38.0      1      0  71.2833   C85  False  False  False  False
# 2         1  26.0      0      0   7.9250   NaN  False   True  False  False
# 3         1  35.0      1      0  53.1000  C123  False  False  False  False
# 4         0  35.0      0      0   8.0500   NaN  False   True   True  False
#
#        S
# 0   True
# 1  False
# 2   True
# 3   True
# 4   True
